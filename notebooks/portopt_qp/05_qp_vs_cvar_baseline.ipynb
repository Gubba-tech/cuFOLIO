# %% [markdown]
# # Unified QP and Mean-CVaR Baseline
#
# Mean-CVaR is an LP/scenario-based, tail-risk-focused cuFOLIO workflow. The PortOpt extension is a QP/objective-and-constraint-focused workflow. They are complementary, and neither replaces the other.

# %%
from cufolio import QPParameters, QuadraticPortfolioOptimizer
from cufolio.cvar_parameters import CvarParameters
backend = "osqp"  # the QP examples default to CPU; switch explicitly to "cuopt"
print("Mean-CVaR: scenario LP")
print("Unified QP: variance, Sharpe, regularization, and linear constraints")
print(QPParameters.__name__, QuadraticPortfolioOptimizer.__name__, CvarParameters.__name__)
