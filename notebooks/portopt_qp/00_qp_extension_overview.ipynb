# %% [markdown]
# # Unified QP Extension Overview
#
# This notebook introduces the CPU-first PortOpt QP layer. Examples use synthetic data and do not claim full CRSP/Compustat/IPCA/AP-Trees replication.

# %%
backend = "osqp"  # switch explicitly to "cuopt" on a configured GPU host
from cufolio import QPParameters, QuadraticPortfolioOptimizer
print(backend, QPParameters.__name__, QuadraticPortfolioOptimizer.__name__)
